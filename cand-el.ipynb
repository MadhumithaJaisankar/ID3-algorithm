# %%
import numpy as np 
import pandas as pd

data = pd.read_csv('C:\\Users\\cse\\3.csv')
concepts = np.array(data.iloc[:,0:-1])
print("\nInstances are:\n",concepts)
target = np.array(data.iloc[:,-1])
print("\nTarget Values are: ",target)

def learn(concepts, target): 
    specific_h = concepts[0].copy()
    print("\nInitialization of specific_h and genearal_h")
    print("\nSpecific Boundary: ", specific_h)
    general_h = [["?" for i in range(len(specific_h))] for i in range(len(specific_h))]
    print("\nGeneric Boundary: ",general_h)  

    for i, h in enumerate(concepts):
        print("\nInstance", i+1 , "is ", h)
        if target[i] == "yes":
            print("Instance is Positive ")
            for x in range(len(specific_h)): 
                if h[x]!= specific_h[x]:                    
                    specific_h[x] ='?'                     
                    general_h[x][x] ='?'
                   
        if target[i] == "no":            
            print("Instance is Negative ")
            for x in range(len(specific_h)): 
                if h[x]!= specific_h[x]:                    
                    general_h[x][x] = specific_h[x]                
                else:                    
                    general_h[x][x] = '?'        
        
        print("Specific Bundary after ", i+1, "Instance is ", specific_h)         
        print("Generic Boundary after ", i+1, "Instance is ", general_h)
        print("\n")

    indices = [i for i, val in enumerate(general_h) if val == ['?', '?', '?', '?', '?', '?']]    
    for i in indices:   
        general_h.remove(['?', '?', '?', '?', '?', '?']) 
    return specific_h, general_h 

s_final, g_final = learn(concepts, target)

print("Final Specific_h: ", s_final, sep="\n")
print("Final General_h: ", g_final, sep="\n")
# Out:
# Instances are:
#  [['sunny' 'warm' 'normal' 'strong' 'same']
#  ['sunny' 'warm' 'high' 'strong' 'same']
#  ['rainy' 'cold' 'high' 'strong' 'change']
#  ['sunny' 'warm' 'high' 'strong' 'change']
#  ['normal' 'cold' 'low' 'moderate' 'change']
#  ['normal' 'warm' 'normal' 'moderate' 'same']
#  ['rainy' 'cold' 'normal' 'strong' 'same']
#  ['normal' 'cold' 'normal' 'low' 'same']
#  ['normal' 'cold' 'normal' 'low' 'same']
#  ['normal' 'cold' 'normal' 'low' 'same']]
#
# Target Values are:  ['yes' 'yes' 'no' 'yes' 'no' 'yes' 'no' 'yes' 'no' 'no']
#
# Initialization of specific_h and genearal_h
#
# Specific Boundary:  ['sunny' 'warm' 'normal' 'strong' 'same']
#
# Generic Boundary:  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
# Instance 1 is  ['sunny' 'warm' 'normal' 'strong' 'same']
# Instance is Positive
# Specific Bundary after  1 Instance is  ['sunny' 'warm' 'normal' 'strong' 'same']
# Generic Boundary after  1 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 2 is  ['sunny' 'warm' 'high' 'strong' 'same']
# Instance is Positive
# Specific Bundary after  2 Instance is  ['sunny' 'warm' '?' 'strong' 'same']
# Generic Boundary after  2 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 3 is  ['rainy' 'cold' 'high' 'strong' 'change']
# Instance is Negative
# Specific Bundary after  3 Instance is  ['sunny' 'warm' '?' 'strong' 'same']
# Generic Boundary after  3 Instance is  [['sunny', '?', '?', '?', '?'], ['?', 'warm', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', 'same']]
#
#
#
# Instance 4 is  ['sunny' 'warm' 'high' 'strong' 'change']
# Instance is Positive
# Specific Bundary after  4 Instance is  ['sunny' 'warm' '?' 'strong' '?']
# Generic Boundary after  4 Instance is  [['sunny', '?', '?', '?', '?'], ['?', 'warm', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 5 is  ['normal' 'cold' 'low' 'moderate' 'change']
# Instance is Negative
# Specific Bundary after  5 Instance is  ['sunny' 'warm' '?' 'strong' '?']
# Generic Boundary after  5 Instance is  [['sunny', '?', '?', '?', '?'], ['?', 'warm', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', 'strong', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 6 is  ['normal' 'warm' 'normal' 'moderate' 'same']
# Instance is Positive
# Specific Bundary after  6 Instance is  ['?' 'warm' '?' '?' '?']
# Generic Boundary after  6 Instance is  [['?', '?', '?', '?', '?'], ['?', 'warm', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 7 is  ['rainy' 'cold' 'normal' 'strong' 'same']
# Instance is Negative
# Specific Bundary after  7 Instance is  ['?' 'warm' '?' '?' '?']
# Generic Boundary after  7 Instance is  [['?', '?', '?', '?', '?'], ['?', 'warm', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 8 is  ['normal' 'cold' 'normal' 'low' 'same']
# Instance is Positive
# Specific Bundary after  8 Instance is  ['?' '?' '?' '?' '?']
# Generic Boundary after  8 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 9 is  ['normal' 'cold' 'normal' 'low' 'same']
# Instance is Negative
# Specific Bundary after  9 Instance is  ['?' '?' '?' '?' '?']
# Generic Boundary after  9 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 10 is  ['normal' 'cold' 'normal' 'low' 'same']
# Instance is Negative
# Specific Bundary after  10 Instance is  ['?' '?' '?' '?' '?']
# Generic Boundary after  10 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
# Final Specific_h:
# ['?' '?' '?' '?' '?']
# Final General_h:
# [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
